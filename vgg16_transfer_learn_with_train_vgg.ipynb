# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.datasets.cifar10 import load_data

from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout

from tensorflow.keras.applications.vgg16 import VGG16
print(tf.__version__)

import matplotlib.pyplot as plt
import os
import random
# Out:
# 2.1.0

# %% [markdown]
# 设置一下cifar10中的类别名称，

# %%
classes_cifar10 = ['airplane','automobile','bird','cat','deer','dog',
                  'frog','horse','ship','truck']

# %% [markdown]
# 引入训练集与测试集

# %%
(X_train, y_train), (X_test,y_test) = load_data()

# %%
X_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
X_train[0].shape
# Out:
# (32, 32, 3)

# %% [markdown]
# 定义方法并查看前几个图片

# %%
def show_images(num):
    for i in range(num):
        idx = random.randint(0,len(X_train))
        plt.imshow(X_train[idx])
        plt.title(classes_cifar10[int(y_train[idx])])
        plt.show()

# %%
show_images(5)

# %%
pre_trained_model = VGG16(input_shape=(32,32,3)
                          ,include_top=False
                          ,weights='imagenet')

# %%
# for layer in pre_trained_model.layers:
#     layer.trainable = False

# %%
for layer in pre_trained_model.layers:
    print(layer.name)
# Out:
# input_2
# block1_conv1
# block1_conv2
# block1_pool
# block2_conv1
# block2_conv2
# block2_pool
# block3_conv1
# block3_conv2
# block3_conv3
# block3_pool
# block4_conv1
# block4_conv2
# block4_conv3
# block4_pool
# block5_conv1
# block5_conv2
# block5_conv3
# block5_pool

# %%
last_layer = pre_trained_model.get_layer('block5_pool')
print('last layer output shape:', last_layer.output_shape)
# Out:
# last layer output shape: (None, 1, 1, 512)

# %%
from tensorflow.keras.layers import Dense, Flatten, BatchNormalization, Dropout

# %%
last_output = last_layer.output
x = Flatten()(last_output)
x = Dense(1024, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(512, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
x = Dense(256, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)
x = Dropout(0.2)(x)
output = Dense(10, activation='softmax')(x)

# %%
model = keras.Model(pre_trained_model.input, output)

# %%
model.compile(optimizer = keras.optimizers.SGD(lr=0.001, momentum=0.9),
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 32, 32, 3)]       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 32, 32, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 32, 32, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 16, 16, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 16, 16, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 16, 16, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 8, 8, 128)         0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 8, 8, 256)         295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 8, 8, 256)         590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 4, 4, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 4, 4, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 2, 2, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 1024)              4096
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               131328
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 128)               32896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 15,937,994
# Trainable params: 15,934,154
# Non-trainable params: 3,840
# _________________________________________________________________

# %%
early_stopping_cb = keras.callbacks.EarlyStopping(monitor='val_loss',patience=10)

# %%
history = model.fit(X_train,y_train, epochs=500, 
                    validation_data=(X_test, y_test),
                   callbacks=[early_stopping_cb])
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/500
# 50000/50000 [==============================] - 50s 998us/sample - loss: 2.0581 - accuracy: 0.2068 - val_loss: 1.7518 - val_accuracy: 0.3094
# Epoch 2/500
# 50000/50000 [==============================] - 48s 954us/sample - loss: 1.7447 - accuracy: 0.2996 - val_loss: 1.5525 - val_accuracy: 0.3858: 1.7 - ETA: 1s - loss: 1.7475 - accura - ETA: 0s - los
# Epoch 3/500
# 50000/50000 [==============================] - 48s 956us/sample - loss: 1.6268 - accuracy: 0.3439 - val_loss: 1.7940 - val_accuracy: 0.3037loss: 1.6591 - ETA: 30s - loss: 1.6599 - acc - ETA: 18s - loss: 1 - ETA: 14s - loss: 1.6426 - accuracy: 0.339 - ETA: 14s - loss: 1.6429 - ETA: 12s - loss: 1.6414  - ETA: 11s - loss: 1.6391 - accuracy - ETA: 6s - loss: 1.6332 - accuracy:  - ETA: 6s - los - ETA: 1s - loss: 1.6264 - accuracy: 0. - ETA: 1s - loss: 1.6267 - accuracy:  - ETA: 0s -
# Epoch 4/500
# 50000/50000 [==============================] - 48s 962us/sample - loss: 1.5338 - accuracy: 0.3757 - val_loss: 1.3938 - val_accuracy: 0.4604s: 1.6008 - accura - ETA: 43s - loss: 1.58 - ETA: 41s - loss: 1.5725 - accuracy: 0 - ETA: 41s - loss: 1.5781 - ETA: 39s - - ETA: 32s - loss: 1.5589 - accuracy - ETA: 31s - loss: 1.5579 - accuracy:  - ETA: 31s - loss: 1.5571 - accuracy: 0.36 - ETA: 31s
# Epoch 5/500
# 50000/50000 [==============================] - 48s 964us/sample - loss: 1.4542 - accuracy: 0.4109 - val_loss: 1.3491 - val_accuracy: 0.4996
# Epoch 6/500
# 50000/50000 [==============================] - 48s 969us/sample - loss: 1.4141 - accuracy: 0.4266 - val_loss: 1.3963 - val_accuracy: 0.4650
# Epoch 7/500
# 50000/50000 [==============================] - 48s 965us/sample - loss: 1.3462 - accuracy: 0.4583 - val_loss: 1.2612 - val_accuracy: 0.5241
# Epoch 8/500
# 50000/50000 [==============================] - 48s 964us/sample - loss: 1.3087 - accuracy: 0.4724 - val_loss: 1.2318 - val_accuracy: 0.5355 accuracy - ETA: 36s - loss: 1.3323 - accuracy: - ETA: 36s -  - ETA: 31s - los - ETA: 29s - loss: 1.3198 - accuracy: 0.46 - ETA: 29s - loss: 1 - ETA: 27s - loss: 1.3213 - accuracy: - ETA: 24s - lo - ETA: 22s - loss:  - ETA: 20s - loss: 1.3261 - accuracy: 0.46 - ETA: 20s - -
# Epoch 9/500
# 50000/50000 [==============================] - 48s 970us/sample - loss: 1.2692 - accuracy: 0.4862 - val_loss: 1.3058 - val_accuracy: 0.4834
# Epoch 10/500
# 50000/50000 [==============================] - 48s 967us/sample - loss: 1.2695 - accuracy: 0.4936 - val_loss: 1.3806 - val_accuracy: 0.4461
# Epoch 11/500
# 50000/50000 [==============================] - 48s 967us/sample - loss: 1.2674 - accuracy: 0.4951 - val_loss: 1.6058 - val_accuracy: 0.4072- loss: 1.262 - ETA: 1s - los - ETA: 0s - loss: 1.2667 - accu
# Epoch 12/500
# 50000/50000 [==============================] - 48s 969us/sample - loss: 1.3058 - accuracy: 0.5025 - val_loss: 6.6063 - val_accuracy: 0.1090
# Epoch 13/500
# 50000/50000 [==============================] - 49s 973us/sample - loss: 1.3829 - accuracy: 0.4675 - val_loss: 1.2186 - val_accuracy: 0.5660
# Epoch 14/500
# 50000/50000 [==============================] - 49s 971us/sample - loss: 1.7547 - accuracy: 0.2991 - val_loss: 1.6284 - val_accuracy: 0.3400
# Epoch 15/500
# 50000/50000 [==============================] - 48s 964us/sample - loss: 1.4221 - accuracy: 0.4277 - val_loss: 1.3204 - val_accuracy: 0.4795
# Epoch 16/500
# 50000/50000 [==============================] - 49s 979us/sample - loss: 0.9540 - accuracy: 0.6544 - val_loss: 0.7529 - val_accuracy: 0.7476
# Epoch 17/500
# 50000/50000 [==============================] - 49s 977us/sample - loss: 0.6375 - accuracy: 0.7950 - val_loss: 0.6078 - val_accuracy: 0.8076
# Epoch 18/500
# 50000/50000 [==============================] - 49s 982us/sample - loss: 0.4793 - accuracy: 0.8495 - val_loss: 0.5598 - val_accuracy: 0.8239
# Epoch 19/500
# 50000/50000 [==============================] - 49s 978us/sample - loss: 0.3869 - accuracy: 0.8784 - val_loss: 0.5363 - val_accuracy: 0.8348
# Epoch 20/500
# 50000/50000 [==============================] - 49s 975us/sample - loss: 0.3197 - accuracy: 0.9017 - val_loss: 0.5736 - val_accuracy: 0.8392
# Epoch 21/500
# 50000/50000 [==============================] - 49s 976us/sample - loss: 0.2667 - accuracy: 0.9195 - val_loss: 0.5856 - val_accuracy: 0.8374
# Epoch 22/500
# 50000/50000 [==============================] - 49s 978us/sample - loss: 0.2208 - accuracy: 0.9326 - val_loss: 0.5661 - val_accuracy: 0.8478
# Epoch 23/500
# 50000/50000 [==============================] - 49s 977us/sample - loss: 0.1834 - accuracy: 0.9444 - val_loss: 0.5415 - val_accuracy: 0.8517
# Epoch 24/500
# 50000/50000 [==============================] - 49s 978us/sample - loss: 0.1553 - accuracy: 0.9538 - val_loss: 0.6736 - val_accuracy: 0.8353
# Epoch 25/500
# 50000/50000 [==============================] - 49s 979us/sample - loss: 0.1346 - accuracy: 0.9609 - val_loss: 0.5995 - val_accuracy: 0.8497- los
# Epoch 26/500
# 50000/50000 [==============================] - 49s 977us/sample - loss: 0.1188 - accuracy: 0.9659 - val_loss: 0.6588 - val_accuracy: 0.8414- ETA: 1s
# Epoch 27/500
# 50000/50000 [==============================] - 49s 975us/sample - loss: 0.1076 - accuracy: 0.9687 - val_loss: 0.6315 - val_accuracy: 0.8474
# Epoch 28/500
# 50000/50000 [==============================] - 49s 979us/sample - loss: 0.0948 - accuracy: 0.9735 - val_loss: 0.6538 - val_accuracy: 0.8444
# Epoch 29/500
# 50000/50000 [==============================] - 49s 978us/sample - loss: 0.0905 - accuracy: 0.9742 - val_loss: 0.6842 - val_accuracy: 0.8450

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['training', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['training', 'validation'], loc='upper left')
plt.show()
